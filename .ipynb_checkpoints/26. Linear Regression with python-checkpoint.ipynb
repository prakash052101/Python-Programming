# %%
import pandas as pd
Boston = pd.read_csv('boston.csv')
Boston
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio   black  lstat  medv
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# ...

# %%
x = Boston.iloc[:, 0:13]
y =  Boston['medv']
print(x.shape)
print(y.shape)
# Out:
# (506, 13)
# (506,)

# %%
x
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio   black  lstat
# 0       15.3  396.90   4.98
# 1       17.8  396.90   9.14
# 2       17.8  392.83   4.03
# ...

# %%
y
# Out:
# 0      24.0
# 1      21.6
# 2      34.7
# 3      33.4
# 4      36.2
#        ...
# 501    22.4
# 502    20.6
# 503    23.9
# 504    22.0
# 505    11.9
# Name: medv, Length: 506, dtype: float64

# %%
import statsmodels.api as sm
x_with_constant = sm.add_constant(x)
x_with_constant
# Out:
#      const     crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0      1.0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1      1.0  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2      1.0  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3      1.0  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4      1.0  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..     ...      ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501    1.0  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502    1.0  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503    1.0  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504    1.0  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505    1.0  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio   black  lstat
# ...

# %%
results = sm.OLS(y, x_with_constant).fit()
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                   medv   R-squared:                       0.741
# Model:                            OLS   Adj. R-squared:                  0.734
# Method:                 Least Squares   F-statistic:                     108.1
# Date:                Wed, 21 Sep 2022   Prob (F-statistic):          6.72e-135
# Time:                        04:52:14   Log-Likelihood:                -1498.8
# No. Observations:                 506   AIC:                             3026.
# Df Residuals:                     492   BIC:                             3085.
# Df Model:                          13
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         36.4595      5.103      7.144      0.000      26.432      46.487
# ...

# %%
# drop insignificant variable
x_with_constant = x_with_constant.drop(['indus', 'age'], axis = 1)
results = sm.OLS(y, x_with_constant).fit()
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                   medv   R-squared:                       0.741
# Model:                            OLS   Adj. R-squared:                  0.735
# Method:                 Least Squares   F-statistic:                     128.2
# Date:                Wed, 21 Sep 2022   Prob (F-statistic):          5.54e-137
# Time:                        04:52:17   Log-Likelihood:                -1498.9
# No. Observations:                 506   AIC:                             3022.
# Df Residuals:                     494   BIC:                             3072.
# Df Model:                          11
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         36.3411      5.067      7.171      0.000      26.385      46.298
# ...

# %%
# making pridictions
pred_medv = results.predict(x_with_constant)
pred_medv
# Out:
# 0      30.124281
# 1      24.996528
# 2      30.533370
# 3      28.647995
# 4      27.982641
#          ...
# 501    23.537900
# 502    22.380817
# 503    27.609999
# 504    26.111333
# 505    22.340843
# Length: 506, dtype: float64

# %%
# cancatinating
Predicted_boston = pd.concat([x_with_constant, y,pd.DataFrame(pred_medv, columns=['Predicted_Price'])], axis = 1)
Predicted_boston
# Out:
#      const     crim    zn  chas    nox     rm     dis  rad  tax  ptratio  \
# 0      1.0  0.00632  18.0     0  0.538  6.575  4.0900    1  296     15.3
# 1      1.0  0.02731   0.0     0  0.469  6.421  4.9671    2  242     17.8
# 2      1.0  0.02729   0.0     0  0.469  7.185  4.9671    2  242     17.8
# 3      1.0  0.03237   0.0     0  0.458  6.998  6.0622    3  222     18.7
# 4      1.0  0.06905   0.0     0  0.458  7.147  6.0622    3  222     18.7
# ..     ...      ...   ...   ...    ...    ...     ...  ...  ...      ...
# 501    1.0  0.06263   0.0     0  0.573  6.593  2.4786    1  273     21.0
# 502    1.0  0.04527   0.0     0  0.573  6.120  2.2875    1  273     21.0
# 503    1.0  0.06076   0.0     0  0.573  6.976  2.1675    1  273     21.0
# 504    1.0  0.10959   0.0     0  0.573  6.794  2.3889    1  273     21.0
# 505    1.0  0.04741   0.0     0  0.573  6.030  2.5050    1  273     21.0
#
#       black  lstat  medv  Predicted_Price
# 0    396.90   4.98  24.0        30.124281
# ...

# %%
# Finding accuracy by each observation
Predicted_boston["Errors"] = abs(Predicted_boston['medv']-Predicted_boston['Predicted_Price'])/Predicted_boston['medv']
Predicted_boston
# Out:
#      const     crim    zn  chas    nox     rm     dis  rad  tax  ptratio  \
# 0      1.0  0.00632  18.0     0  0.538  6.575  4.0900    1  296     15.3
# 1      1.0  0.02731   0.0     0  0.469  6.421  4.9671    2  242     17.8
# 2      1.0  0.02729   0.0     0  0.469  7.185  4.9671    2  242     17.8
# 3      1.0  0.03237   0.0     0  0.458  6.998  6.0622    3  222     18.7
# 4      1.0  0.06905   0.0     0  0.458  7.147  6.0622    3  222     18.7
# ..     ...      ...   ...   ...    ...    ...     ...  ...  ...      ...
# 501    1.0  0.06263   0.0     0  0.573  6.593  2.4786    1  273     21.0
# 502    1.0  0.04527   0.0     0  0.573  6.120  2.2875    1  273     21.0
# 503    1.0  0.06076   0.0     0  0.573  6.976  2.1675    1  273     21.0
# 504    1.0  0.10959   0.0     0  0.573  6.794  2.3889    1  273     21.0
# 505    1.0  0.04741   0.0     0  0.573  6.030  2.5050    1  273     21.0
#
#       black  lstat  medv  Predicted_Price    Errors
# ...

# %%
# Finding accuracy of overall model
1 - Predicted_boston.Errors.mean()
# Out:
# 0.8357528910010064

# %%
# Making a predictions on unseen data - Make sure indus and age ie, variable not modeled are not available
new_house = pd.DataFrame({'const':[1], 'crim':[0.01], 'zn':[21.6], 'chas':[0], 'nox':[0.65], 'rm':[7.89],
                         'dis':[4.91], 'rad':[1.2], 'tax':[355.2], 'ptratio':[18.36], 'black':[476.28], 'lstat':[5.98]})
new_house
# Out:
#    const  crim    zn  chas   nox    rm   dis  rad    tax  ptratio   black  \
# 0      1  0.01  21.6     0  0.65  7.89  4.91  1.2  355.2    18.36  476.28
#
#    lstat
# 0   5.98

# %%
results.predict(new_house)
# Out:
# 0    28.799117
# dtype: float64
